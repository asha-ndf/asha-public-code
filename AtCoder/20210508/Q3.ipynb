# %%
N = int(input())
A = input().split(' ')
B = []
for k in A:
  B.append(int(k))
C = 0
for j in range(1,N):
  T = B[j]
  for i in range(j):
    if (B[i] - T)%200 ==0:
      C = C+1
print(int(C))
# Out:
# 6
# 123 223 123 523 200 2000
# 4
