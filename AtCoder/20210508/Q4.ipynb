# %%
a = input('').split('')
N = a[0]
K = a[1]
list1=[]
list2=[]
for h in range(N):
  for i in range(N):
    for j in range(N):
      list1.append(h+i+j)
      list2.append(str(h+1) + ' ' + str(i+1) + ' ' + str(j+1))
list1.sort()
