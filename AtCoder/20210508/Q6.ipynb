# %%
S = input()
K = input()
C = 0
D = 1
S = S*int(K)
for i in range(1,len(S)):
  if S[i] =='?':
    D = D+1
  else:
    if S[i-1] =='?':
      D = D+1
    elif S[i] != S[i-1]:
      C = C+1
ans = 2**(D+1) + (2**D)*C -1
print(ans)
# Out:
# ?1?
# 1
# 15
