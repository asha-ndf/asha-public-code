# %%
N = int(input())
ans = []
a = int((N - N%8)/8 +1)
base = [6,10,12,15,18,20,24,30]
for i in range(a):
  ans.extend(list(map(lambda x: x+i*30,base)))
if N ==3:
  print('6 10 15')
else:
  print(*ans[:N])
# Out:
# 3
# 6 10 15
