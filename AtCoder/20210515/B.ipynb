# %%
a = int(input())
name1 =''
name2 =''
high1 =0
high2 =0
for i in range(a):
  temp = input().split(' ')
  hight = int(temp[1])
  if hight >high1:
    high2 = high1
    name2 = name1
    high1 = hight
    name1 = temp[0]
  elif hight > high2:
    high2 = hight
    name2 = temp[0]

print(name2)
