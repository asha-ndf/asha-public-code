# %%
S = input()
a = 0
b = 0
for i in S:
  if i == 'o':
    a = a+1
  elif i == '?':
    b = b+1

if a>4:
  print(0)
elif a ==4:
  print(24)
elif a ==3:
  print(24*b + 36)
elif a == 2:
  print((b+2)**4+2*((b+1)**4) + b**4)
elif a == 1:
  print((b+1)**4 - b**4)
else:
  print(b**4)
