# %%
N = int(input())
bs = 10**18
for i in range(100):
  if 2**i > N:
    break
  else:
    c = N % (2 ** i)
    a = (N - c) / (2**i)
    if a+i+c < bs:
      bs = a+i+c
print(int(bs))
# Out:
# 998244353
# 143.0
