# %%
import bisect 
N, K =list(map(int, input().split(' ')))
nowp = 0
As =[]
Bs = []
for i in range(N):
  A, B =list(map(int, input().split(' ')))
  if As
'''
def BubbleSort(As,Bs):
  for i in range(len(As)):
    for j in range(len(As)-1, i, -1):
      if As[j] < As[j-1]:
        As[j], As[j-1] = As[j-1], As[j]
        Bs[j], Bs[j-1] = Bs[j-1], Bs[j]
  return As,Bs

uA, uB = BubbleSort(As,Bs)
'''
uA,uB = As,Bs
for i in range(N):
  A = uA[i]
  B = uB[i]
  if A-nowp <=K:
    K = K+nowp-A+B
    nowp = A
  else:
    print(nowp+K)
    exit()
  if nowp > 10**100:
    print(10**100+1)
    exit()
if nowp>10**100:
  print(10**100+1)
else:
  print(nowp+K)
